# %% [markdown]
# # Projeto Final Big Data Engineer Semantix Academy
#
# Autor: **Renato Holzlsauer Mattos Macedo**<br>
# Contato: renato.holzlsauer@gmail.com

# %%
import os
import requests
import zipfile
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %% [markdown]
# # 1. Download dos arquivos e envio para o HDFS

# %%
def download_unzip_file(directory, filename, url):
    path_to_file = os.path.join(directory, filename)

    if not os.path.exists(directory):
        os.mkdir(directory)

    if not os.path.exists(path_to_file):
        request = requests.get(url, allow_redirects=True)
        with open(path_to_file, 'wb') as f:
            f.write(request.content)
        with zipfile.ZipFile(path_to_file, 'r') as file:
            file.extractall(directory)
            
        print(f'Arquivo salvo com sucesso em: {directory}')

# %%
download_unzip_file('./data', 'covid-data.zip', 'https://github.com/Holzlsauer/semantix-covid/blob/main/HIST_PAINEL_COVIDBR.zip?raw=true')

# %%
# Criação do diretório local
# !mkdir -p data

# %%
# Verificação dos arquivos extraidos
# !ls -l ./data/
# Out:
# total 242808
# -rw-r--r-- 1 root root 62492959 Apr 22 00:09 HIST_PAINEL_COVIDBR_2020_Parte1_06jul2021.csv
# -rw-r--r-- 1 root root 76520681 Apr 22 00:09 HIST_PAINEL_COVIDBR_2020_Parte2_06jul2021.csv
# -rw-r--r-- 1 root root 91120916 Apr 22 00:09 HIST_PAINEL_COVIDBR_2021_Parte1_06jul2021.csv
# -rw-r--r-- 1 root root  3046774 Apr 22 00:09 HIST_PAINEL_COVIDBR_2021_Parte2_06jul2021.csv
# -rw-r--r-- 1 root root 15431753 Apr 22 00:09 covid-data.zip

# %%
# Criação do diretório no hdfs
# !hdfs dfs -mkdir -p /user/data/covid

# %%
# Envio para o hdfs
# !hdfs dfs -put ./data/*.csv /user/data/covid
# Out:
# put: `/user/data/covid/HIST_PAINEL_COVIDBR_2020_Parte1_06jul2021.csv': File exists
# put: `/user/data/covid/HIST_PAINEL_COVIDBR_2020_Parte2_06jul2021.csv': File exists
# put: `/user/data/covid/HIST_PAINEL_COVIDBR_2021_Parte1_06jul2021.csv': File exists
# put: `/user/data/covid/HIST_PAINEL_COVIDBR_2021_Parte2_06jul2021.csv': File exists

# %%
# Verificação do envio para o hdfs
# !hdfs dfs -ls -R /user/data
# Out:
# drwxr-xr-x   - root supergroup          0 2022-04-22 00:12 /user/data/covid
# -rw-r--r--   2 root supergroup   62492959 2022-04-22 00:12 /user/data/covid/HIST_PAINEL_COVIDBR_2020_Parte1_06jul2021.csv
# -rw-r--r--   2 root supergroup   76520681 2022-04-22 00:12 /user/data/covid/HIST_PAINEL_COVIDBR_2020_Parte2_06jul2021.csv
# -rw-r--r--   2 root supergroup   91120916 2022-04-22 00:12 /user/data/covid/HIST_PAINEL_COVIDBR_2021_Parte1_06jul2021.csv
# -rw-r--r--   2 root supergroup    3046774 2022-04-22 00:12 /user/data/covid/HIST_PAINEL_COVIDBR_2021_Parte2_06jul2021.csv

# %% [markdown]
# # 2. Otimização para tabela HIVE com particionamento por município

# %%
data = spark.read.csv('/user/data/covid', sep=';', header='true')
# data.printSchema()

# %%
# Ajustes da tipagem dos dados após leitura
data = data.withColumnRenamed('interior/metropolitana', 'interior_metropolitana')
data = data\
    .withColumn('regiao', col('regiao').cast(StringType()))\
    .withColumn('estado', col('estado').cast(StringType()))\
    .withColumn('municipio', col('municipio').cast(StringType()))\
    .withColumn('coduf', col('coduf').cast(IntegerType()))\
    .withColumn('codmun', col('codmun').cast(IntegerType()))\
    .withColumn('codRegiaoSaude', col('codRegiaoSaude').cast(IntegerType()))\
    .withColumn('nomeRegiaoSaude', col('nomeRegiaoSaude').cast(StringType()))\
    .withColumn('semanaEpi', col('semanaEpi').cast(IntegerType()))\
    .withColumn('populacaoTCU2019', col('populacaoTCU2019').cast(IntegerType()))\
    .withColumn('casosAcumulado', col('casosAcumulado').cast(IntegerType()))\
    .withColumn('casosNovos', col('casosNovos').cast(IntegerType()))\
    .withColumn('obitosAcumulado', col('obitosAcumulado').cast(IntegerType()))\
    .withColumn('obitosNovos', col('obitosNovos').cast(IntegerType()))\
    .withColumn('Recuperadosnovos', col('Recuperadosnovos').cast(IntegerType()))\
    .withColumn('emAcompanhamentoNovos', col('emAcompanhamentoNovos').cast(IntegerType()))\
    .withColumn('interior_metropolitana', col('interior_metropolitana').cast(StringType()))\
    .withColumn('data', col('data').cast(TimestampType()))

data.printSchema()
# Out:
# root
#  |-- regiao: string (nullable = true)
#  |-- estado: string (nullable = true)
#  |-- municipio: string (nullable = true)
#  |-- coduf: integer (nullable = true)
#  |-- codmun: integer (nullable = true)
#  |-- codRegiaoSaude: integer (nullable = true)
#  |-- nomeRegiaoSaude: string (nullable = true)
#  |-- data: timestamp (nullable = true)
#  |-- semanaEpi: integer (nullable = true)
#  |-- populacaoTCU2019: integer (nullable = true)
#  |-- casosAcumulado: integer (nullable = true)
#  |-- casosNovos: integer (nullable = true)
#  |-- obitosAcumulado: integer (nullable = true)
#  |-- obitosNovos: integer (nullable = true)
#  |-- Recuperadosnovos: integer (nullable = true)
#  |-- emAcompanhamentoNovos: integer (nullable = true)
#  |-- interior_metropolitana: string (nullable = true)

# %%
# Preenchendo valores nulos de municipio para particionamento por municipio
data = data.withColumn('municipio', rtrim(ltrim(lower(col('municipio'))))).fillna({'municipio': 'nulo'})

# %%
# Salvando tabela havi em formato orc
data.cache()
data.write.format('orc').mode('overwrite').partitionBy('municipio').saveAsTable('covid_data')

# %%
# Verificação da criação da tabela hive
# !hdfs dfs -ls /user/hive/warehouse/covid_data
# Out:
# Found 5299 items
# -rw-r--r--   2 root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/_SUCCESS
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=abadia de goiás
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=abadia dos dourados
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=abadiânia
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=abaetetuba
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=abaeté
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=abaiara
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=abaré
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=abatiá
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=abaíra
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=abdon batista
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=abel figueiredo
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=abelardo luz
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=abre campo
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=abreu e lima
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=abreulândia
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=acaiaca
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=acajutiba
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=acarape
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=acaraú
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=acari
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=acará
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=acauã
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=aceguá
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=acopiara
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=acorizal
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=acrelândia
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=acreúna
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=adamantina
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=adelândia
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=adolfo
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=adrianópolis
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=adustina
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=afogados da ingazeira
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=afonso bezerra
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=afonso cláudio
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=afonso cunha
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=afrânio
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=afuá
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=agrestina
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=agricolândia
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=agrolândia
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=agronômica
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=aguanil
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=aguaí
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=agudo
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=agudos
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=agudos do sul
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=aguiar
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=aguiarnópolis
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=aimorés
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=aiquara
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=aiuaba
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=aiuruoca
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=ajuricaba
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=alagoa
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=alagoa grande
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=alagoa nova
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=alagoinha
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=alagoinha do piauí
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=alagoinhas
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=alambari
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=albertina
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=alcantil
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=alcinópolis
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=alcobaça
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=alcântara
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=alcântaras
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=aldeias altas
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=alecrim
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=xangri-lá
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=xanxerê
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=xapuri
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=xavantina
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=xaxim
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=xexéu
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=xinguara
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=xique-xique
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=zabelê
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=zacarias
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=zortéa
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=zé doca
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=água azul do norte
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=água boa
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=água branca
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=água clara
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=água comprida
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=água doce
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=água doce do maranhão
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=água doce do norte
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=água fria
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=água fria de goiás
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=água limpa
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=água nova
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=água preta
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=água santa
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=águas belas
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=águas da prata
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=águas de chapecó
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=águas de lindóia
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=águas de santa bárbara
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=águas de são pedro
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=águas formosas
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=águas frias
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=águas lindas de goiás
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=águas mornas
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=águas vermelhas
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=águia branca
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=álvares florence
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=álvares machado
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=álvaro de carvalho
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=áurea
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=ângulo
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=érico cardoso
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=óbidos
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data/municipio=óleo

# %%
# Eliminando leitura armazenada
del data

# %% [markdown]
# # 3. Criação das visualizações

# %%
covid_data = spark.read.table('covid_data')

# %%
covid_data.printSchema()
# Out:
# root
#  |-- regiao: string (nullable = true)
#  |-- estado: string (nullable = true)
#  |-- coduf: integer (nullable = true)
#  |-- codmun: integer (nullable = true)
#  |-- codRegiaoSaude: integer (nullable = true)
#  |-- nomeRegiaoSaude: string (nullable = true)
#  |-- data: timestamp (nullable = true)
#  |-- semanaEpi: integer (nullable = true)
#  |-- populacaoTCU2019: integer (nullable = true)
#  |-- casosAcumulado: integer (nullable = true)
#  |-- casosNovos: integer (nullable = true)
#  |-- obitosAcumulado: integer (nullable = true)
#  |-- obitosNovos: integer (nullable = true)
#  |-- Recuperadosnovos: integer (nullable = true)
#  |-- emAcompanhamentoNovos: integer (nullable = true)
#  |-- interior_metropolitana: string (nullable = true)
#  |-- municipio: string (nullable = true)

# %%
# Preenchendo nulls com 0
covid_data = covid_data\
    .fillna({'populacaoTCU2019': 0})\
    .fillna({'casosAcumulado': 0})\
    .fillna({'casosNovos': 0})\
    .fillna({'obitosAcumulado': 0})\
    .fillna({'obitosNovos': 0})\
    .fillna({'Recuperadosnovos': 0})\
    .fillna({'emAcompanhamentoNovos': 0})

# %%
# Identificando último data de dados coletados
covid_data.select(max('data')).show()
# Out:
# +-------------------+
# |          max(data)|
# +-------------------+
# |2021-07-06 00:00:00|
# +-------------------+

# %% [markdown]
# ### Primeira visualização

# %%
# Visualizando dados do último dia de dados coletados
first_view = covid_data.where(col('data') == '2021-07-06')\
    .select('Recuperadosnovos', 'emAcompanhamentoNovos')\
    .agg(sum('Recuperadosnovos').alias('casos_recuperados'), \
        (sum('emAcompanhamentoNovos')).alias('em_acompanhamento'))

first_view.show()
# Out:
# +-----------------+-----------------+
# |casos_recuperados|em_acompanhamento|
# +-----------------+-----------------+
# |         17262646|          1065477|
# +-----------------+-----------------+

# %% [markdown]
# ### Segunda visualização

# %%
second_view = covid_data.where(col('data') == '2021-07-06')\
.agg(max('casosAcumulado').alias('acumulado'), \
     max('casosNovos').alias('casos_novos'), \
     regexp_replace((format_number(((sum('casosAcumulado') * 100000) / sum('populacaoTCU2019')), 1))\
        .cast(StringType()), '\,', '').alias('incidencia'))

second_view.show()
# Out:
# +---------+-----------+----------+
# |acumulado|casos_novos|incidencia|
# +---------+-----------+----------+
# | 18855015|      62504|    8972.3|
# +---------+-----------+----------+

# %% [markdown]
# ### Terceira visualização

# %%
third_view = covid_data.where(col('data') == '2021-07-06')\
.agg(max('obitosAcumulado').alias('obitos_acumulados'), \
     max('obitosNovos').alias('casos_novos'), \
     regexp_replace((format_number(((sum('obitosAcumulado') * 100000) / sum('populacaoTCU2019')), 1))\
        .cast(StringType()), '\,', '').alias('mortalidade'), \
     regexp_replace((format_number(((max('obitosNovos') * 100) / max('casosNovos')), 1))\
        .cast(StringType()), '\,', '').alias('letalidade'))

third_view.show()
# Out:
# +-----------------+-----------+-----------+----------+
# |obitos_acumulados|casos_novos|mortalidade|letalidade|
# +-----------------+-----------+-----------+----------+
# |           526892|       1780|      250.7|       2.8|
# +-----------------+-----------+-----------+----------+

# %% [markdown]
# Os coef. de **incidência**, **mortalidade** e **letalidade** foram calculados seguindo as fórmula expostas na seção **Sobre** no site [https://covid.saude.gov.br/](https://covid.saude.gov.br/)

# %% [markdown]
# # 4. Salvar a primeira visualização como tabela Hive

# %%
first_view.createOrReplaceTempView('first_tmp_view')

spark.sql('create table if not exists first_view as select * from first_tmp_view');

# %%
# !hdfs dfs -ls /user/hive/warehouse
# Out:
# Found 3 items
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data
# drwxrwxr-x   - root supergroup          0 2022-04-28 01:36 /user/hive/warehouse/first_view
# drwxr-xr-x   - root supergroup          0 2022-04-28 23:19 /user/hive/warehouse/second_view

# %%
spark.read.table('first_view').show()
# Out:
# +-----------------+-----------------+
# |casos_recuperados|em_acompanhamento|
# +-----------------+-----------------+
# |         17262646|          1065477|
# +-----------------+-----------------+

# %% [markdown]
# # 5. Salvar a segunda visualização no formato parquet com compressão snappy

# %%
second_view.write.parquet('/user/hive/warehouse/second_view', mode='overwrite', compression='snappy')

# %%
# !hdfs dfs -ls /user/hive/warehouse
# Out:
# Found 3 items
# drwxr-xr-x   - root supergroup          0 2022-04-26 23:29 /user/hive/warehouse/covid_data
# drwxrwxr-x   - root supergroup          0 2022-04-28 01:36 /user/hive/warehouse/first_view
# drwxr-xr-x   - root supergroup          0 2022-04-28 23:19 /user/hive/warehouse/second_view

# %%
spark.read.parquet('/user/hive/warehouse/second_view').show()
# Out:
# +---------+-----------+----------+
# |acumulado|casos_novos|incidencia|
# +---------+-----------+----------+
# | 18855015|      62504|    8972.3|
# +---------+-----------+----------+

# %% [markdown]
# # 6. Salvar a terceira visualização em um tópico kafka

# %% [markdown]
# Tópico criado no kafka:
#
#     kafka-topics.sh --bootstrap-server kafka:9092 --topic third_view --create --partitions 1 --replication-factor 1

# %%
third_view_save = third_view.withColumn('value', struct(
    col('obitos_acumulados'),\
    col('casos_novos'),\
    col('mortalidade'),\
    col('letalidade')
).cast(StringType()))

third_view_save.printSchema()
# Out:
# root
#  |-- obitos_acumulados: integer (nullable = true)
#  |-- casos_novos: integer (nullable = true)
#  |-- mortalidade: string (nullable = true)
#  |-- letalidade: string (nullable = true)
#  |-- value: string (nullable = false)

# %%
third_view_save.write.format('kafka')\
    .option('kafka.bootstrap.servers', 'kafka:9092')\
    .option('topic','third_view').save()

# %% [markdown]
# # 7. Criar a visualização pelo Spark com os dados enviados para o HDFS

# %%
third_view.withColumn('value', struct(
    col('obitos_acumulados'),\
    col('casos_novos'),\
    col('mortalidade'),\
    col('letalidade')
)).show()
# Out:
# +-----------------+-----------+-----------+----------+--------------------+
# |obitos_acumulados|casos_novos|mortalidade|letalidade|               value|
# +-----------------+-----------+-----------+----------+--------------------+
# |           526892|       1780|      250.7|       2.8|[526892, 1780, 25...|
# +-----------------+-----------+-----------+----------+--------------------+

# %%
covid_data = spark.read.table('covid_data')
covid_data.printSchema()
# Out:
# root
#  |-- regiao: string (nullable = true)
#  |-- estado: string (nullable = true)
#  |-- coduf: integer (nullable = true)
#  |-- codmun: integer (nullable = true)
#  |-- codRegiaoSaude: integer (nullable = true)
#  |-- nomeRegiaoSaude: string (nullable = true)
#  |-- data: timestamp (nullable = true)
#  |-- semanaEpi: integer (nullable = true)
#  |-- populacaoTCU2019: integer (nullable = true)
#  |-- casosAcumulado: integer (nullable = true)
#  |-- casosNovos: integer (nullable = true)
#  |-- obitosAcumulado: integer (nullable = true)
#  |-- obitosNovos: integer (nullable = true)
#  |-- Recuperadosnovos: integer (nullable = true)
#  |-- emAcompanhamentoNovos: integer (nullable = true)
#  |-- interior_metropolitana: string (nullable = true)
#  |-- municipio: string (nullable = true)

# %%
brasil = covid_data.where((col('regiao') == 'Brasil') & (col('data') == '2021-07-06'))\
.agg(
    max('regiao').alias('regiao'),
    max('casosAcumulado').alias('casos'),
    max('obitosAcumulado').alias('obitos'),
    regexp_replace((format_number(((sum('casosAcumulado') * 100000) / sum('populacaoTCU2019')), 1))\
        .cast(StringType()), '\,', '').alias('incidencia'),
    regexp_replace((format_number(((sum('obitosAcumulado') * 100000) / sum('populacaoTCU2019')), 1))\
        .cast(StringType()), '\,', '').alias('mortalidade')
)

brasil.show()
# Out:
# +------+--------+------+----------+-----------+
# |regiao|   casos|obitos|incidencia|mortalidade|
# +------+--------+------+----------+-----------+
# |Brasil|18855015|526892|    8972.3|      250.7|
# +------+--------+------+----------+-----------+

# %%
regioes = covid_data.where((col('regiao') != 'Brasil') & (col('data') == '2021-07-06'))\
.groupBy('regiao').agg(
    max('casosAcumulado').alias('casos'),
    max('obitosAcumulado').alias('obitos'),
    regexp_replace((format_number(((sum('casosAcumulado') * 100000) / sum('populacaoTCU2019')), 1))\
        .cast(StringType()), '\,', '').alias('incidencia'),
    regexp_replace((format_number(((sum('obitosAcumulado') * 100000) / sum('populacaoTCU2019')), 1))\
        .cast(StringType()), '\,', '').alias('mortalidade')
)

regioes.show()
# Out:
# +------------+-------+------+----------+-----------+
# |      regiao|  casos|obitos|incidencia|mortalidade|
# +------------+-------+------+----------+-----------+
# |    Nordeste|1141612| 24428|    7807.3|      188.9|
# |         Sul|1308643| 31867|   12046.4|      269.2|
# |     Sudeste|3809222|130389|    8078.2|      277.6|
# |Centro-Oeste| 686433| 19485|   11760.5|      301.9|
# |       Norte| 557708| 15624|    9401.6|      237.9|
# +------------+-------+------+----------+-----------+

# %%
# Realizando o append dos dataframes e mantendo os dados do Brasil no topo
view = brasil.union(regioes)
view.show()
# Out:
# +------------+--------+------+----------+-----------+
# |      regiao|   casos|obitos|incidencia|mortalidade|
# +------------+--------+------+----------+-----------+
# |      Brasil|18855015|526892|    8972.3|      250.7|
# |    Nordeste| 1141612| 24428|    7807.3|      188.9|
# |         Sul| 1308643| 31867|   12046.4|      269.2|
# |     Sudeste| 3809222|130389|    8078.2|      277.6|
# |Centro-Oeste|  686433| 19485|   11760.5|      301.9|
# |       Norte|  557708| 15624|    9401.6|      237.9|
# +------------+--------+------+----------+-----------+
